# %%
# prepare data for GRU
from pandas import DataFrame
from pandas import read_csv
from numpy import array
from numpy import sqrt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import SpatialDropout1D
import matplotlib.pyplot as plt

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix - 1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load dataset
dataset = read_csv('/content/drive/My Drive/fusedData158324.csv', header=0, index_col=0)
mean_value = dataset['vehiclecount'].mean()
dataset['vehiclecount'].fillna(value=mean_value, inplace=True)

values = dataset.values

# %%
# specify columns to plot
groups = [0, 1, 2, 3, 4, 5]
i = 1
# plot each column
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(dataset.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
# ensure all data is float
values = values.astype('float32')

# %%
# choose a number of time steps
n_steps = 1

# %%
# convert into input/output
X, y = split_sequences(values, n_steps)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
# reshape the data
n_features = X.shape[2]
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1] * n_features))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1] * n_features))

# %%
...
# define model
model = Sequential()
model.add(GRU(200, input_shape=(n_steps * n_features, 1)))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# %%
# fit network
history = model.fit(x_train, y_train, epochs=50, batch_size=100, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 141/141 - 8s - loss: 25.9689 - val_loss: 25.7667 - 8s/epoch - 56ms/step
# Epoch 2/50
# 141/141 - 1s - loss: 25.0259 - val_loss: 25.2729 - 973ms/epoch - 7ms/step
# Epoch 3/50
# 141/141 - 1s - loss: 24.2275 - val_loss: 25.0574 - 862ms/epoch - 6ms/step
# Epoch 4/50
# 141/141 - 1s - loss: 23.6636 - val_loss: 23.8138 - 1s/epoch - 10ms/step
# Epoch 5/50
# 141/141 - 2s - loss: 22.8686 - val_loss: 22.8835 - 2s/epoch - 11ms/step
# Epoch 6/50
# 141/141 - 1s - loss: 22.1762 - val_loss: 22.1512 - 1s/epoch - 8ms/step
# Epoch 7/50
# 141/141 - 1s - loss: 21.3067 - val_loss: 21.3326 - 637ms/epoch - 5ms/step
# Epoch 8/50
# 141/141 - 1s - loss: 20.4441 - val_loss: 20.5076 - 610ms/epoch - 4ms/step
# Epoch 9/50
# 141/141 - 1s - loss: 19.4890 - val_loss: 19.5045 - 610ms/epoch - 4ms/step
# Epoch 10/50
# 141/141 - 1s - loss: 18.6983 - val_loss: 18.5789 - 604ms/epoch - 4ms/step
# Epoch 11/50
# 141/141 - 1s - loss: 17.9738 - val_loss: 18.1695 - 553ms/epoch - 4ms/step
# Epoch 12/50
# 141/141 - 1s - loss: 17.2161 - val_loss: 18.2595 - 597ms/epoch - 4ms/step
# Epoch 13/50
# 141/141 - 1s - loss: 16.6414 - val_loss: 17.0700 - 608ms/epoch - 4ms/step
# Epoch 14/50
# 141/141 - 1s - loss: 16.2933 - val_loss: 17.2126 - 550ms/epoch - 4ms/step
# Epoch 15/50
# 141/141 - 1s - loss: 15.8492 - val_loss: 16.4329 - 535ms/epoch - 4ms/step
# Epoch 16/50
# 141/141 - 1s - loss: 15.5229 - val_loss: 15.8278 - 548ms/epoch - 4ms/step
# Epoch 17/50
# 141/141 - 1s - loss: 15.2590 - val_loss: 16.0974 - 537ms/epoch - 4ms/step
# Epoch 18/50
# 141/141 - 1s - loss: 14.7622 - val_loss: 15.6844 - 625ms/epoch - 4ms/step
# Epoch 19/50
# 141/141 - 1s - loss: 14.7346 - val_loss: 14.8438 - 598ms/epoch - 4ms/step
# Epoch 20/50
# 141/141 - 1s - loss: 14.0481 - val_loss: 15.0384 - 553ms/epoch - 4ms/step
# Epoch 21/50
# 141/141 - 1s - loss: 13.9094 - val_loss: 15.3677 - 534ms/epoch - 4ms/step
# Epoch 22/50
# 141/141 - 1s - loss: 13.8523 - val_loss: 14.5171 - 529ms/epoch - 4ms/step
# Epoch 23/50
# 141/141 - 1s - loss: 13.3841 - val_loss: 14.7255 - 615ms/epoch - 4ms/step
# Epoch 24/50
# 141/141 - 1s - loss: 13.3594 - val_loss: 14.1898 - 635ms/epoch - 5ms/step
# Epoch 25/50
# 141/141 - 1s - loss: 12.9480 - val_loss: 13.7809 - 739ms/epoch - 5ms/step
# Epoch 26/50
# 141/141 - 1s - loss: 12.9253 - val_loss: 14.2473 - 790ms/epoch - 6ms/step
# Epoch 27/50
# 141/141 - 1s - loss: 12.7945 - val_loss: 14.3241 - 771ms/epoch - 5ms/step
# Epoch 28/50
# 141/141 - 1s - loss: 12.6145 - val_loss: 13.2078 - 818ms/epoch - 6ms/step
# Epoch 29/50
# 141/141 - 1s - loss: 12.3566 - val_loss: 13.8368 - 617ms/epoch - 4ms/step
# Epoch 30/50
# 141/141 - 1s - loss: 12.3257 - val_loss: 13.7417 - 607ms/epoch - 4ms/step
# Epoch 31/50
# 141/141 - 1s - loss: 12.0473 - val_loss: 13.1673 - 514ms/epoch - 4ms/step
# Epoch 32/50
# 141/141 - 1s - loss: 11.7553 - val_loss: 13.2287 - 544ms/epoch - 4ms/step
# Epoch 33/50
# 141/141 - 1s - loss: 11.7698 - val_loss: 13.6281 - 524ms/epoch - 4ms/step
# Epoch 34/50
# 141/141 - 1s - loss: 11.6053 - val_loss: 13.2497 - 539ms/epoch - 4ms/step
# Epoch 35/50
# 141/141 - 1s - loss: 11.5792 - val_loss: 12.5321 - 609ms/epoch - 4ms/step
# Epoch 36/50
# 141/141 - 1s - loss: 11.5911 - val_loss: 12.5498 - 564ms/epoch - 4ms/step
# Epoch 37/50
# 141/141 - 1s - loss: 11.7003 - val_loss: 12.8681 - 607ms/epoch - 4ms/step
# Epoch 38/50
# 141/141 - 1s - loss: 11.4083 - val_loss: 12.8016 - 542ms/epoch - 4ms/step
# Epoch 39/50
# 141/141 - 1s - loss: 11.3535 - val_loss: 12.7068 - 559ms/epoch - 4ms/step
# Epoch 40/50
# 141/141 - 1s - loss: 11.3199 - val_loss: 12.8819 - 546ms/epoch - 4ms/step
# Epoch 41/50
# 141/141 - 1s - loss: 11.2904 - val_loss: 12.9004 - 619ms/epoch - 4ms/step
# Epoch 42/50
# 141/141 - 1s - loss: 11.0217 - val_loss: 12.3353 - 522ms/epoch - 4ms/step
# Epoch 43/50
# 141/141 - 1s - loss: 10.9276 - val_loss: 12.6869 - 546ms/epoch - 4ms/step
# Epoch 44/50
# 141/141 - 1s - loss: 10.9301 - val_loss: 12.9276 - 611ms/epoch - 4ms/step
# Epoch 45/50
# 141/141 - 1s - loss: 10.7539 - val_loss: 12.4672 - 546ms/epoch - 4ms/step
# Epoch 46/50
# 141/141 - 1s - loss: 10.6743 - val_loss: 12.6286 - 620ms/epoch - 4ms/step
# Epoch 47/50
# 141/141 - 1s - loss: 10.6941 - val_loss: 12.1141 - 752ms/epoch - 5ms/step
# Epoch 48/50
# 141/141 - 1s - loss: 10.7031 - val_loss: 12.3220 - 802ms/epoch - 6ms/step
# Epoch 49/50
# 141/141 - 1s - loss: 10.7951 - val_loss: 11.6108 - 776ms/epoch - 6ms/step
# Epoch 50/50
# 141/141 - 1s - loss: 10.1721 - val_loss: 12.6252 - 743ms/epoch - 5ms/step

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.reshape(y_pred.shape[0])
# Out:
# 110/110 [==============================] - 1s 2ms/step

# %%
print("RMSE on Test Data = ", sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE on Test Data = ", metrics.mean_absolute_error(y_test, y_pred))
print("R2 on Test Data = ", metrics.r2_score(y_test, y_pred))
# Out:
# RMSE on Test Data =  3.5531957
# MAE on Test Data =  2.5325046
# R2 on Test Data =  0.5225478868255322

# %%
df1 = DataFrame({'Actual': y_test, 'Predicted': y_pred, 'variance': y_test - y_pred})
df1.head()
# Out:
#    Actual  Predicted  variance
# 0     0.0   1.977675 -1.977675
# 1     1.0   3.271664 -2.271664
# 2     0.0   0.054367 -0.054367
# 3     3.0   3.712838 -0.712838
# 4     1.0   1.311790 -0.311790

# %%
x_ax = range(len(x_test))
plt.plot(x_ax, y_test, lw=0.5, color='blue', label='observed')
plt.plot(x_ax, y_pred, lw=0.5, color='red', label='predicted')
plt.legend(loc='best')
plt.grid()
