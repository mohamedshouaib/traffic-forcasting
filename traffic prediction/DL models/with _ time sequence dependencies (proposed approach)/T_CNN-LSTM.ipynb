# %%
# prepare data for CNN_LSTM
from pandas import read_csv
from pandas import DataFrame
from numpy import array
from numpy import sqrt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Flatten
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
import matplotlib.pyplot as plt

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix - 1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# load dataset
dataset = read_csv('/content/drive/My Drive/fusedData158324.csv', header=0, index_col=0)
mean_value = dataset['vehiclecount'].mean()
dataset['vehiclecount'].fillna(value=mean_value, inplace=True)

values = dataset.values

# %%
# specify columns to plot
groups = [0, 1, 2, 3, 4, 5]
i = 1
# plot each column
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(dataset.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
# ensure all data is float
values = values.astype('float32')

# %%
# choose a number of time steps
n_steps = 132

# %%
# convert into input/output
X, y = split_sequences(values, n_steps)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
# reshape the data
n_features = X.shape[2]
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1] * n_features))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1] * n_features))

# %%
...
# design network
model = Sequential()
model.add(Conv1D(filters=16, kernel_size=4, activation='relu', input_shape=(n_steps * n_features, 1)))
model.add(MaxPooling1D(pool_size=2))
model.add(LSTM(200))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# %%
# fit network
history = model.fit(x_train, y_train, epochs=50, batch_size=100, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 140/140 - 16s - loss: 26.4247 - val_loss: 25.5041 - 16s/epoch - 115ms/step
# Epoch 2/50
# 140/140 - 4s - loss: 25.1389 - val_loss: 24.6157 - 4s/epoch - 32ms/step
# Epoch 3/50
# 140/140 - 5s - loss: 23.8467 - val_loss: 23.2646 - 5s/epoch - 33ms/step
# Epoch 4/50
# 140/140 - 5s - loss: 22.8039 - val_loss: 22.2475 - 5s/epoch - 32ms/step
# Epoch 5/50
# 140/140 - 5s - loss: 21.6969 - val_loss: 22.1918 - 5s/epoch - 32ms/step
# Epoch 6/50
# 140/140 - 5s - loss: 20.9728 - val_loss: 20.2636 - 5s/epoch - 33ms/step
# Epoch 7/50
# 140/140 - 5s - loss: 19.7553 - val_loss: 19.9318 - 5s/epoch - 33ms/step
# Epoch 8/50
# 140/140 - 5s - loss: 18.7517 - val_loss: 17.6987 - 5s/epoch - 33ms/step
# Epoch 9/50
# 140/140 - 5s - loss: 17.7196 - val_loss: 16.8217 - 5s/epoch - 33ms/step
# Epoch 10/50
# 140/140 - 5s - loss: 16.7513 - val_loss: 16.4644 - 5s/epoch - 33ms/step
# Epoch 11/50
# 140/140 - 5s - loss: 15.7866 - val_loss: 15.5637 - 5s/epoch - 33ms/step
# Epoch 12/50
# 140/140 - 5s - loss: 14.9485 - val_loss: 15.6357 - 5s/epoch - 34ms/step
# Epoch 13/50
# 140/140 - 5s - loss: 14.4255 - val_loss: 13.7494 - 5s/epoch - 32ms/step
# Epoch 14/50
# 140/140 - 5s - loss: 13.4930 - val_loss: 13.6537 - 5s/epoch - 32ms/step
# Epoch 15/50
# 140/140 - 5s - loss: 13.2096 - val_loss: 12.8305 - 5s/epoch - 34ms/step
# Epoch 16/50
# 140/140 - 4s - loss: 12.5725 - val_loss: 12.6351 - 4s/epoch - 32ms/step
# Epoch 17/50
# 140/140 - 5s - loss: 12.1047 - val_loss: 12.1052 - 5s/epoch - 32ms/step
# Epoch 18/50
# 140/140 - 5s - loss: 11.5931 - val_loss: 12.5724 - 5s/epoch - 32ms/step
# Epoch 19/50
# 140/140 - 4s - loss: 11.3935 - val_loss: 11.9170 - 4s/epoch - 32ms/step
# Epoch 20/50
# 140/140 - 5s - loss: 14.3897 - val_loss: 12.2339 - 5s/epoch - 32ms/step
# Epoch 21/50
# 140/140 - 5s - loss: 11.5998 - val_loss: 12.4857 - 5s/epoch - 39ms/step
# Epoch 22/50
# 140/140 - 5s - loss: 10.8919 - val_loss: 11.8427 - 5s/epoch - 32ms/step
# Epoch 23/50
# 140/140 - 5s - loss: 10.6242 - val_loss: 11.6522 - 5s/epoch - 33ms/step
# Epoch 24/50
# 140/140 - 5s - loss: 10.9811 - val_loss: 12.0852 - 5s/epoch - 33ms/step
# Epoch 25/50
# 140/140 - 5s - loss: 10.3928 - val_loss: 11.3898 - 5s/epoch - 32ms/step
# Epoch 26/50
# 140/140 - 5s - loss: 10.4481 - val_loss: 10.9145 - 5s/epoch - 33ms/step
# Epoch 27/50
# 140/140 - 5s - loss: 9.8940 - val_loss: 10.4175 - 5s/epoch - 33ms/step
# Epoch 28/50
# 140/140 - 5s - loss: 9.5829 - val_loss: 10.4164 - 5s/epoch - 32ms/step
# Epoch 29/50
# 140/140 - 5s - loss: 9.5424 - val_loss: 9.5059 - 5s/epoch - 33ms/step
# Epoch 30/50
# 140/140 - 5s - loss: 9.2991 - val_loss: 9.5997 - 5s/epoch - 32ms/step
# Epoch 31/50
# 140/140 - 5s - loss: 9.1504 - val_loss: 9.3775 - 5s/epoch - 34ms/step
# Epoch 32/50
# 140/140 - 5s - loss: 8.9866 - val_loss: 10.1970 - 5s/epoch - 33ms/step
# Epoch 33/50
# 140/140 - 5s - loss: 8.8969 - val_loss: 9.6556 - 5s/epoch - 33ms/step
# Epoch 34/50
# 140/140 - 5s - loss: 9.6939 - val_loss: 9.6597 - 5s/epoch - 32ms/step
# Epoch 35/50
# 140/140 - 5s - loss: 8.9434 - val_loss: 9.2602 - 5s/epoch - 33ms/step
# Epoch 36/50
# 140/140 - 5s - loss: 8.7128 - val_loss: 8.6998 - 5s/epoch - 32ms/step
# Epoch 37/50
# 140/140 - 4s - loss: 8.7280 - val_loss: 9.0612 - 4s/epoch - 32ms/step
# Epoch 38/50
# 140/140 - 5s - loss: 8.2057 - val_loss: 8.6199 - 5s/epoch - 33ms/step
# Epoch 39/50
# 140/140 - 5s - loss: 8.4659 - val_loss: 10.3254 - 5s/epoch - 32ms/step
# Epoch 40/50
# 140/140 - 5s - loss: 8.7803 - val_loss: 10.1896 - 5s/epoch - 32ms/step
# Epoch 41/50
# 140/140 - 5s - loss: 8.4446 - val_loss: 8.5919 - 5s/epoch - 33ms/step
# Epoch 42/50
# 140/140 - 5s - loss: 8.1804 - val_loss: 8.7729 - 5s/epoch - 34ms/step
# Epoch 43/50
# 140/140 - 5s - loss: 8.1114 - val_loss: 8.8800 - 5s/epoch - 32ms/step
# Epoch 44/50
# 140/140 - 5s - loss: 7.7591 - val_loss: 8.8224 - 5s/epoch - 33ms/step
# Epoch 45/50
# 140/140 - 5s - loss: 8.5681 - val_loss: 8.2306 - 5s/epoch - 32ms/step
# Epoch 46/50
# 140/140 - 5s - loss: 7.7970 - val_loss: 8.4197 - 5s/epoch - 32ms/step
# Epoch 47/50
# 140/140 - 5s - loss: 7.6811 - val_loss: 7.9668 - 5s/epoch - 33ms/step
# Epoch 48/50
# 140/140 - 5s - loss: 7.5903 - val_loss: 8.2304 - 5s/epoch - 34ms/step
# Epoch 49/50
# 140/140 - 5s - loss: 7.9002 - val_loss: 8.6936 - 5s/epoch - 32ms/step
# Epoch 50/50
# 140/140 - 5s - loss: 8.0323 - val_loss: 8.5546 - 5s/epoch - 33ms/step

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.reshape(y_pred.shape[0])
# Out:
# 109/109 [==============================] - 1s 8ms/step

# %%
print("RMSE on Test Data = ", sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE on Test Data = ", metrics.mean_absolute_error(y_test, y_pred))
print("R2 on Test Data = ", metrics.r2_score(y_test, y_pred))
# Out:
# RMSE on Test Data =  2.9248219
# MAE on Test Data =  1.9567131
# R2 on Test Data =  0.6745536136173687

# %%
df1 = DataFrame({'Actual': y_test, 'Predicted': y_pred, 'variance': y_test - y_pred})
df1.head()
# Out:
#    Actual  Predicted  variance
# 0     3.0   3.919215 -0.919215
# 1     3.0   3.741399 -0.741399
# 2     0.0   0.580124 -0.580124
# 3     5.0   6.444017 -1.444017
# 4    19.0  11.563710  7.436290

# %%
x_ax = range(len(x_test))
plt.plot(x_ax, y_test, lw=0.5, color='blue', label='observed')
plt.plot(x_ax, y_pred, lw=0.5, color='red', label='predicted')
plt.legend(loc='best')
plt.grid()
