# %%
# prepare data for GRU
from pandas import DataFrame
from pandas import read_csv
from numpy import array
from numpy import sqrt
from sklearn import metrics
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import GRU
from keras.layers import Dense
from keras.layers import SpatialDropout1D
import matplotlib.pyplot as plt

# %%
# split a multivariate sequence into samples
def split_sequences(sequences, n_steps):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps
        # check if we are beyond the dataset
        if end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix - 1, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load dataset
dataset = read_csv('/content/drive/My Drive/fusedData158324.csv', header=0, index_col=0)
mean_value = dataset['vehiclecount'].mean()
dataset['vehiclecount'].fillna(value=mean_value, inplace=True)

values = dataset.values

# %%
# specify columns to plot
groups = [0, 1, 2, 3, 4, 5]
i = 1
# plot each column
plt.figure()
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(dataset.columns[group], y=0.5, loc='right')
    i += 1
plt.show()

# %%
# ensure all data is float
values = values.astype('float32')

# %%
# choose a number of time steps
n_steps = 132

# %%
# convert into input/output
X, y = split_sequences(values, n_steps)

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=50)

# %%
# reshape the data
n_features = X.shape[2]
x_train = x_train.reshape((x_train.shape[0], x_train.shape[1] * n_features))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1] * n_features))

# %%
...
# define model
model = Sequential()
model.add(GRU(200, input_shape=(n_steps * n_features, 1)))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# %%
# fit network
history = model.fit(x_train, y_train, epochs=50, batch_size=100, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 140/140 - 15s - loss: 26.5046 - val_loss: 25.4890 - 15s/epoch - 106ms/step
# Epoch 2/50
# 140/140 - 7s - loss: 25.2798 - val_loss: 24.5297 - 7s/epoch - 47ms/step
# Epoch 3/50
# 140/140 - 8s - loss: 24.0560 - val_loss: 22.8832 - 8s/epoch - 58ms/step
# Epoch 4/50
# 140/140 - 7s - loss: 22.5911 - val_loss: 23.1010 - 7s/epoch - 48ms/step
# Epoch 5/50
# 140/140 - 7s - loss: 21.0958 - val_loss: 19.7969 - 7s/epoch - 48ms/step
# Epoch 6/50
# 140/140 - 7s - loss: 19.4208 - val_loss: 17.5873 - 7s/epoch - 48ms/step
# Epoch 7/50
# 140/140 - 7s - loss: 18.1963 - val_loss: 16.8966 - 7s/epoch - 49ms/step
# Epoch 8/50
# 140/140 - 7s - loss: 18.1175 - val_loss: 15.0056 - 7s/epoch - 48ms/step
# Epoch 9/50
# 140/140 - 7s - loss: 15.7868 - val_loss: 15.2419 - 7s/epoch - 49ms/step
# Epoch 10/50
# 140/140 - 7s - loss: 14.0572 - val_loss: 14.7372 - 7s/epoch - 48ms/step
# Epoch 11/50
# 140/140 - 7s - loss: 17.2322 - val_loss: 21.0790 - 7s/epoch - 48ms/step
# Epoch 12/50
# 140/140 - 7s - loss: 14.7676 - val_loss: 12.7899 - 7s/epoch - 48ms/step
# Epoch 13/50
# 140/140 - 7s - loss: 14.9116 - val_loss: 13.2088 - 7s/epoch - 48ms/step
# Epoch 14/50
# 140/140 - 7s - loss: 13.9937 - val_loss: 13.6767 - 7s/epoch - 48ms/step
# Epoch 15/50
# 140/140 - 7s - loss: 12.9698 - val_loss: 11.8129 - 7s/epoch - 49ms/step
# Epoch 16/50
# 140/140 - 7s - loss: 12.8139 - val_loss: 12.2332 - 7s/epoch - 49ms/step
# Epoch 17/50
# 140/140 - 7s - loss: 11.5019 - val_loss: 11.3342 - 7s/epoch - 50ms/step
# Epoch 18/50
# 140/140 - 7s - loss: 11.0747 - val_loss: 10.4265 - 7s/epoch - 49ms/step
# Epoch 19/50
# 140/140 - 7s - loss: 10.5988 - val_loss: 12.0824 - 7s/epoch - 49ms/step
# Epoch 20/50
# 140/140 - 7s - loss: 10.9540 - val_loss: 10.7997 - 7s/epoch - 49ms/step
# Epoch 21/50
# 140/140 - 7s - loss: 9.8870 - val_loss: 11.4489 - 7s/epoch - 49ms/step
# Epoch 22/50
# 140/140 - 7s - loss: 10.1635 - val_loss: 10.2158 - 7s/epoch - 48ms/step
# Epoch 23/50
# 140/140 - 7s - loss: 10.2212 - val_loss: 11.1701 - 7s/epoch - 48ms/step
# Epoch 24/50
# 140/140 - 7s - loss: 9.8476 - val_loss: 10.1308 - 7s/epoch - 48ms/step
# Epoch 25/50
# 140/140 - 7s - loss: 9.4215 - val_loss: 10.8783 - 7s/epoch - 49ms/step
# Epoch 26/50
# 140/140 - 7s - loss: 19.2085 - val_loss: 17.9419 - 7s/epoch - 48ms/step
# Epoch 27/50
# 140/140 - 7s - loss: 16.7286 - val_loss: 15.6335 - 7s/epoch - 49ms/step
# Epoch 28/50
# 140/140 - 7s - loss: 14.2316 - val_loss: 12.3600 - 7s/epoch - 49ms/step
# Epoch 29/50
# 140/140 - 7s - loss: 11.2856 - val_loss: 11.2933 - 7s/epoch - 49ms/step
# Epoch 30/50
# 140/140 - 7s - loss: 11.8440 - val_loss: 11.1599 - 7s/epoch - 49ms/step
# Epoch 31/50
# 140/140 - 7s - loss: 11.3330 - val_loss: 15.7195 - 7s/epoch - 49ms/step
# Epoch 32/50
# 140/140 - 7s - loss: 11.4452 - val_loss: 10.0480 - 7s/epoch - 49ms/step
# Epoch 33/50
# 140/140 - 7s - loss: 9.8775 - val_loss: 11.5108 - 7s/epoch - 49ms/step
# Epoch 34/50
# 140/140 - 7s - loss: 10.2482 - val_loss: 10.5493 - 7s/epoch - 48ms/step
# Epoch 35/50
# 140/140 - 7s - loss: 8.9258 - val_loss: 9.1608 - 7s/epoch - 49ms/step
# Epoch 36/50
# 140/140 - 7s - loss: 8.6496 - val_loss: 9.9673 - 7s/epoch - 49ms/step
# Epoch 37/50
# 140/140 - 7s - loss: 8.4459 - val_loss: 9.3378 - 7s/epoch - 48ms/step
# Epoch 38/50
# 140/140 - 7s - loss: 8.1669 - val_loss: 10.4308 - 7s/epoch - 48ms/step
# Epoch 39/50
# 140/140 - 7s - loss: 8.6993 - val_loss: 9.2839 - 7s/epoch - 49ms/step
# Epoch 40/50
# 140/140 - 7s - loss: 8.4567 - val_loss: 7.9080 - 7s/epoch - 48ms/step
# Epoch 41/50
# 140/140 - 7s - loss: 9.0366 - val_loss: 8.4729 - 7s/epoch - 49ms/step
# Epoch 42/50
# 140/140 - 7s - loss: 10.0434 - val_loss: 9.2759 - 7s/epoch - 48ms/step
# Epoch 43/50
# 140/140 - 7s - loss: 8.0374 - val_loss: 7.7070 - 7s/epoch - 49ms/step
# Epoch 44/50
# 140/140 - 7s - loss: 7.5422 - val_loss: 7.9169 - 7s/epoch - 49ms/step
# Epoch 45/50
# 140/140 - 7s - loss: 7.7219 - val_loss: 7.6254 - 7s/epoch - 49ms/step
# Epoch 46/50
# 140/140 - 7s - loss: 7.2039 - val_loss: 7.7337 - 7s/epoch - 48ms/step
# Epoch 47/50
# 140/140 - 7s - loss: 7.4410 - val_loss: 7.8238 - 7s/epoch - 49ms/step
# Epoch 48/50
# 140/140 - 7s - loss: 9.1443 - val_loss: 10.0213 - 7s/epoch - 49ms/step
# Epoch 49/50
# 140/140 - 7s - loss: 10.2609 - val_loss: 8.7174 - 7s/epoch - 49ms/step
# Epoch 50/50
# 140/140 - 7s - loss: 7.7324 - val_loss: 8.4535 - 7s/epoch - 49ms/step

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
y_pred = model.predict(x_test)
y_pred = y_pred.reshape(y_pred.shape[0])
# Out:
# 109/109 [==============================] - 2s 11ms/step

# %%
print("RMSE on Test Data = ", sqrt(metrics.mean_squared_error(y_test, y_pred)))
print("MAE on Test Data = ", metrics.mean_absolute_error(y_test, y_pred))
print("R2 on Test Data = ", metrics.r2_score(y_test, y_pred))
# Out:
# RMSE on Test Data =  2.907483
# MAE on Test Data =  2.0391202
# R2 on Test Data =  0.6784007815613413

# %%
df1 = DataFrame({'Actual': y_test, 'Predicted': y_pred, 'variance': y_test - y_pred})
df1.head()
# Out:
#    Actual  Predicted  variance
# 0     3.0   5.085438 -2.085438
# 1     3.0   2.151579  0.848421
# 2     0.0   1.790548 -1.790548
# 3     5.0   5.421242 -0.421242
# 4    19.0  12.624642  6.375358

# %%
x_ax = range(len(x_test))
plt.plot(x_ax, y_test, lw=0.5, color='blue', label='observed')
plt.plot(x_ax, y_pred, lw=0.5, color='red', label='predicted')
plt.legend(loc='best')
plt.grid()
